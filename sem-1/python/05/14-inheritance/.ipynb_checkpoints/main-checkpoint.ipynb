# %%
class Person:
    def __init__(self, age, gender):
        self.age = age
        self.gender = gender

class Teacher(Person):
    def __init__(self, age, gender):
        super().__init__(age, gender)

    def teaches(self):
        print("I am a Teacher")

class Student(Person):
    def __init__(self, age, gender):
        super().__init__(age, gender)

    def studies(self):
        print("I Study")

person = Person(10, "asdf")

Teacher(40, "male").teaches()
Student(21, "female").studies()
# Out:
# I am a Teacher
# I Study
